# %%
import pandas as pd 
import matplotlib.pyplot as plt
import zipfile
import datetime
import numpy as np 
import os 
import shutil

# %%
string='210812'


path2 = 'D:/CENTRO COVID/CIC19-main/datos/generales/'+string+'/'
os.mkdir(path2) # Este comando crea el folder en el desktop con la fecha del día 

#Corres primero los primeros dos chunks

# %%
#pathcarpetadescargas="C:/Users/Luis Sequeira/Downloads/datos_abiertos_covid19 (29).zip"

#zf = zipfile.ZipFile(pathcarpetadescargas) 
#archivo=pd.read_csv(zf.open(string+'COVID19MEXICO.csv'),encoding='latin1',low_memory=True)

#archivo.to_csv('D:/CENTRO COVID/CIC19-main/datos/generales/'+string+'/'+string+'COVID19MEXICO.csv')

# %%
#string = datetime.datetime.today().strftime('%y%m%d') #fecha de base de datos


hoy=datetime.datetime.today()
#Si lo corres la mañana siguiente

hoy= hoy - datetime.timedelta(days=1)

corte = hoy - datetime.timedelta(days=12) #hoy-12dias

#La base ya debe estar descargada

#zf = zipfile.ZipFile(path2+string+'COVID19MEXICO.zip') 
#base_covid = pd.read_csv(zf.open(string+'COVID19MEXICO.csv'),encoding='latin1',low_memory=True) 
#base_covid = pd.read_csv(zf.open('COVID19MEXICO.csv'),encoding='latin1')
base_covid = pd.read_csv(path2+string+'COVID19MEXICO.csv',encoding='latin1',low_memory=True)


base_covid
# Out:
# D:\CENTRO COVID\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2021-08-12      z482b8       2      12           9     2
# 1                2021-08-12      z49a69       1      12          23     1
# 2                2021-08-12      z23d9d       1      12          22     2
# 3                2021-08-12      z24953       1      12           9     1
# 4                2021-08-12      zz8e77       2      12           9     2
# ...                     ...         ...     ...     ...         ...   ...
# 8963232          2021-08-12      d0a4c8       2       4          26     2
# 8963233          2021-08-12      9d3302       2      12          27     1
# 8963234          2021-08-12      a70ec8       2      12          25     2
# 8963235          2021-08-12      74d90e       2      12           9     2
# 8963236          2021-08-12      d77dca       2      12          31     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                  9            9             12              1  ...
# 1                 23           23              4              2  ...
# 2                 24           22              9              1  ...
# 3                  9            9             10              1  ...
# 4                  9            9              2              1  ...
# ...              ...          ...            ...            ...  ...
# 8963232           26           26             18              1  ...
# 8963233           27           27              4              1  ...
# 8963234           25           25              8              1  ...
# 8963235            9            9              7              1  ...
# 8963236           31           31             50              1  ...
#
#         OTRO_CASO TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 0               2                2            97                      2
# 1               1                2            97                      2
# 2               2                2            97                      2
# 3               1                1             2                      2
# 4               2                2            97                      2
# ...           ...              ...           ...                    ...
# 8963232         2                2            97                      1
# 8963233         2                1             3                      2
# 8963234         2                2            97                      1
# 8963235         2                2            97                      1
# 8963236         2                2            97                      1
#
#          RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                        97                    1        99            MÃ©xico
# 1                        97                    2        99            MÃ©xico
# 2                        97                    6        99            MÃ©xico
# 3                        97                    7        99            MÃ©xico
# 4                        97                    6        99            MÃ©xico
# ...                     ...                  ...       ...                ...
# 8963232                   2                    7        99            MÃ©xico
# 8963233                  97                    6        99            MÃ©xico
# 8963234                   2                    7        99            MÃ©xico
# 8963235                   2                    7        99            MÃ©xico
# 8963236                   1                    3        99            MÃ©xico
#
#          PAIS_ORIGEN  UCI
# 0                 97   97
# 1                 97    1
# 2                 97   97
# 3                 97   97
# 4                 97   97
# ...              ...  ...
# 8963232           97   97
# 8963233           97   97
# 8963234           97   97
# 8963235           97   97
# 8963236           97   97
#
# [8963237 rows x 40 columns]

# %%
base_covid=base_covid[base_covid['CLASIFICACION_FINAL'].isin([1,2,3])] #positivo covid
base_cdmx=base_covid[base_covid['ENTIDAD_RES']==9] #de la CDMX
base_cdmx=base_cdmx[base_cdmx['MUNICIPIO_RES']!=999] #con alcaldia identificada
base_cdmx
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2021-08-12      z482b8       2      12           9     2
# 15               2021-08-12      z2770b       1      12           9     1
# 20               2021-08-12      zz9079       2      12           9     1
# 37               2021-08-12      z23c2e       2      12           9     1
# 55               2021-08-12      z3d1e2       2      12           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8963204          2021-08-12      6e9e95       2      12           9     2
# 8963210          2021-08-12      e2b608       2      12           9     1
# 8963213          2021-08-12      95e732       2      12           9     1
# 8963221          2021-08-12      a5469d       2      12           9     1
# 8963228          2021-08-12      daa6e0       2      12           9     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                  9            9             12              1  ...
# 15                 9            9              6              1  ...
# 20                 9            9              7              1  ...
# 37                 9            9              5              1  ...
# 55                 9            9              5              1  ...
# ...              ...          ...            ...            ...  ...
# 8963204            9            9             17              1  ...
# 8963210            9            9             10              1  ...
# 8963213            9            9             11              1  ...
# 8963221            9            9             10              1  ...
# 8963228            9            9              3              1  ...
#
#         OTRO_CASO TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 0               2                2            97                      2
# 15              1                1             1                      2
# 20              1                2            97                      2
# 37              2                2            97                      2
# 55              1                1             1                      2
# ...           ...              ...           ...                    ...
# 8963204         1                2            97                      1
# 8963210         2                2            97                      1
# 8963213         1                2            97                      1
# 8963221         1                2            97                      1
# 8963228         2                2            97                      1
#
#          RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                        97                    1        99            MÃ©xico
# 15                       97                    3        99            MÃ©xico
# 20                       97                    1        99            MÃ©xico
# 37                       97                    1        99            MÃ©xico
# 55                       97                    3        99            MÃ©xico
# ...                     ...                  ...       ...                ...
# 8963204                   1                    3        99            MÃ©xico
# 8963210                   1                    3        99            MÃ©xico
# 8963213                   1                    3        99            MÃ©xico
# 8963221                   1                    3        99            MÃ©xico
# 8963228                   1                    3        99            MÃ©xico
#
#          PAIS_ORIGEN  UCI
# 0                 97   97
# 15                97   97
# 20                97   97
# 37                97   97
# 55                97   97
# ...              ...  ...
# 8963204           97   97
# 8963210           97   97
# 8963213           97   97
# 8963221           97   97
# 8963228           97   97
#
# [833789 rows x 40 columns]

# %%
base_cdmx.loc[base_cdmx['FECHA_DEF'] == '9999-99-99', 'FECHA_DEF'] = pd.NaT #9999-99-99 pasa a ser NaT
base_cdmx['FECHA_DEF']=pd.to_datetime(base_cdmx['FECHA_DEF']) #los valores de la columna pasan a ser datetime
base_cdmx['FECHA_SINTOMAS']=pd.to_datetime(base_cdmx['FECHA_SINTOMAS']) #los valores de la columna pasan a ser datetime

base_def=base_cdmx.dropna() #eliminamos los NA, NaN y NaT
base_def
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 399              2021-08-12      eb3a6b       2       4           9     2
# 10082            2021-08-12      a6e282       1      12           9     2
# 11145            2021-08-12      72af18       2      12           9     2
# 11614            2021-08-12      c781c3       2      12           9     1
# 12109            2021-08-12      72f3bc       2       4           9     1
# ...                     ...         ...     ...     ...         ...   ...
# 8915126          2021-08-12      dea275       2       4           9     1
# 8915512          2021-08-12      e38c06       2      12           9     2
# 8916085          2021-08-12      bf80da       2      12           9     1
# 8917345          2021-08-12      cf123d       2      12           9     2
# 8935575          2021-08-12      728cf8       2       4           9     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 399                9            9             17              2  ...
# 10082              9            9              5              2  ...
# 11145              9            9              7              2  ...
# 11614              9            9              7              2  ...
# 12109              9            9             10              2  ...
# ...              ...          ...            ...            ...  ...
# 8915126            9            9             17              2  ...
# 8915512            9            9             17              2  ...
# 8916085           30            9              2              2  ...
# 8917345            9            9              5              2  ...
# 8935575            9            9             10              2  ...
#
#         OTRO_CASO TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 399             2                1             1                      1
# 10082           2                1             1                      2
# 11145           2                1             4                      1
# 11614           2                1             4                      1
# 12109           1                2            97                      1
# ...           ...              ...           ...                    ...
# 8915126         2                1             1                      2
# 8915512         2                2            97                      1
# 8916085         1                2            97                      1
# 8917345         2                2            97                      2
# 8935575         1                2            97                      1
#
#          RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 399                       2                    3        99            MÃ©xico
# 10082                    97                    3        99            MÃ©xico
# 11145                     1                    3        99            MÃ©xico
# 11614                     1                    3        99            MÃ©xico
# 12109                     1                    3        99            MÃ©xico
# ...                     ...                  ...       ...                ...
# 8915126                  97                    3        99            MÃ©xico
# 8915512                   1                    3        99            MÃ©xico
# 8916085                   1                    3        99            MÃ©xico
# 8917345                  97                    1        99            MÃ©xico
# 8935575                   1                    3        99            MÃ©xico
#
#          PAIS_ORIGEN  UCI
# 399               97    2
# 10082             97    2
# 11145             97    2
# 11614             97    2
# 12109             97    2
# ...              ...  ...
# 8915126           97    2
# 8915512           97    2
# 8916085           97    2
# 8917345           97    2
# 8935575           97    2
#
# [36412 rows x 40 columns]

# %%
path3 = 'D:/CENTRO COVID/CIC19-main/datos/generales/general/'
delegacion=pd.read_excel(path3+'Delegaciones.xlsx')
delegacion
# Out:
#     CLAVE_MUNICIPIO               MUNICIPIO  POBLACION
# 0                 2            AZCAPOTZALCO     400161
# 1                 3                COYOACÁN     608479
# 2                 4   CUAJIMALPA DE MORELOS     199224
# 3                 5       GUSTAVO A. MADERO    1164477
# 4                 6               IZTACALCO     390348
# 5                 7              IZTAPALAPA    1827868
# 6                 8  LA MAGDALENA CONTRERAS     243886
# 7                 9              MILPA ALTA     137927
# 8                10          ÁLVARO OBREGÓN     749982
# 9                11                 TLÁHUAC     361593
# 10               12                 TLALPAN     677104
# 11               13              XOCHIMILCO     415933
# 12               14           BENITO JUÁREZ     417416
# 13               15              CUAUHTÉMOC     532553
# 14               16          MIGUEL HIDALGO     364439
# 15               17     VENUSTIANO CARRANZA     427263

# %%
defs={}
defs_tot={}
defs_avg={}

for i in range(0,16):
    defs[i]=base_def[base_def['MUNICIPIO_RES']==i+2].pivot_table(index=['FECHA_DEF'], aggfunc='size') #Contar muertes por dia en cada municipio
    defs[i]=pd.DataFrame(defs[i]) #lo anterior a dataframe
    idx=pd.date_range(defs[i].index[0],hoy) #creamos un indice de fechas desde el primer registro hasta hoy
    defs[i]=defs[i].reindex(idx, fill_value=0) #reindexamos el df para no saltarnos fechas
    defs_tot[i]=defs[i].cumsum()*(100000/delegacion['POBLACION'][i]) #el acumulado dia a dia por 100 mil habs
    defs_avg[i]=defs[i].rolling(window=7).mean()*(100000/delegacion['POBLACION'][i]) #defunciones diarias por 100 mil habs (promedio movil)

# %%
con={}
con_tot={}
con_avg={}

for i in range(0,16):
    con[i]=base_cdmx[base_cdmx['MUNICIPIO_RES']==i+2].pivot_table(index=['FECHA_SINTOMAS'], aggfunc='size') #contar casos nuevos por dia
    con[i]=pd.DataFrame(con[i]) #lo anterior como dataframe
    idx=pd.date_range(con[i].index[0],hoy) #creamos un indice de fechas desde el primer registro hasta hoy
    con[i]=con[i].reindex(idx, fill_value=0) #reindexamos el df para no saltarnos fechas
    con_tot[i]=con[i].cumsum()*(100000/delegacion['POBLACION'][i]) #el acumulado dia a dia por 100 mil habs
    con_avg[i]=con[i].rolling(window=7).mean()*(100000/delegacion['POBLACION'][i]) #promedio movil de casos diarios por 100 mil habs

# %%
def_dia=[] #cada valor de la serie corresponde a una delegacion, todas las delegaciones en la misma fecha
def_cum=[]
caso_dia=[]
caso_cum=[]

for i in range(len(delegacion)):
    def_dia.append(defs_avg[i].iloc[-13,-1]) #en la serie de defunciones diarias agregamos el valor hace 12 dias
    def_cum.append(defs_tot[i].iloc[-1,-1]) #en la serie de defunciones acumuladas agregamos el ultimo valor
    caso_dia.append(con_avg[i].iloc[-13,-1]) #en la serie de casos diarios agregamos el valor de hace 12 dias
    caso_cum.append(con_tot[i].iloc[-1,-1]) #en la serie de casos acumulados agregamos el ultimo valor

# %%
delegacion['DEF_DIA']=def_dia
delegacion['DEF_CUM']=def_cum
delegacion['CASO_DIA']=caso_dia
delegacion['CASO_CUM']=caso_cum

# %%
import geopandas as gpd

# %%
shapefile = 'D:/CENTRO COVID/CIC19-main/CDMX/alcaldias/alcaldias.shp' #direccion del shp
gdf = gpd.read_file(shapefile)[['municipio','geometry']] #leemos el shp, solo las columnas municipio y geometry
#gdf

# %%
gdf['CLAVE_MUNICIPIO']=pd.DataFrame([9,14,5,2,6,10,13,17,12,4,15,7,3,16,8,11]) #creamos las claves de los municipios, sin esto no se puede juntar el geodataframe y el df
gdf
# Out:
#    municipio                                           geometry  \
# 0          9  POLYGON ((-98.99723 19.22731, -98.99745 19.227...
# 1         14  POLYGON ((-99.13679 19.40156, -99.13682 19.401...
# 2          5  POLYGON ((-99.11860 19.58446, -99.11691 19.581...
# 3          2  POLYGON ((-99.18231 19.50748, -99.18229 19.507...
# 4          6  POLYGON ((-99.05584 19.42196, -99.05589 19.421...
# 5         10  POLYGON ((-99.18871 19.39475, -99.18868 19.394...
# 6         13  POLYGON ((-99.09870 19.31964, -99.09849 19.319...
# 7         17  POLYGON ((-99.10895 19.45273, -99.10889 19.452...
# 8         12  POLYGON ((-99.19629 19.30228, -99.19595 19.302...
# 9          4  POLYGON ((-99.25698 19.40043, -99.25694 19.400...
# 10        15  POLYGON ((-99.12919 19.46247, -99.12884 19.462...
# 11         7  POLYGON ((-99.05813 19.40072, -99.05814 19.400...
# 12         3  POLYGON ((-99.13923 19.35687, -99.13772 19.356...
# 13        16  POLYGON ((-99.19058 19.46794, -99.19066 19.465...
# 14         8  POLYGON ((-99.20859 19.33610, -99.20867 19.335...
# 15        11  POLYGON ((-98.97893 19.32393, -98.97856 19.323...
#
#     CLAVE_MUNICIPIO
# 0                 9
# 1                14
# 2                 5
# 3                 2
# 4                 6
# 5                10
# 6                13
# 7                17
# 8                12
# 9                 4
# 10               15
# 11                7
# 12                3
# 13               16
# 14                8
# 15               11

# %%
gdf = gdf.merge(delegacion, left_on = 'CLAVE_MUNICIPIO', right_on = 'CLAVE_MUNICIPIO', how = 'left') #juntamos geodataframe y df
#gdf

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable 
# import mapclassify 

fig, ax = plt.subplots(figsize = (15,11))
divider = make_axes_locatable(ax)

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)

import matplotlib as mpl

cmap = mpl.cm.Reds(np.linspace(0,1,20))
#cmap = x
cmap = mpl.colors.ListedColormap(cmap[3:15,:-1])

# Defunciones diarias 

cax = divider.append_axes('bottom', size = '5%', pad = 0.1)
cax.tick_params(labelsize=15)

gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

gdf.plot(column = 'DEF_DIA', ax = ax, cax = cax, cmap = cmap, legend = True, legend_kwds={'orientation':'horizontal'})
plt.title('Defunciones diarias por 100 mil habs.\n',fontsize=20)
plt.savefig(path2 + 'cdmx-def-diarias.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# <ipython-input-15-031e09522bf5>:21: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

# %%
fig, ax = plt.subplots(figsize = (15,11))
divider = make_axes_locatable(ax)

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)

#import matplotlib as mpl

#cmap = mpl.cm.Reds(np.linspace(0,1,20))
#cmap = mpl.colors.ListedColormap(cmap[5:,:-1])

# Defunciones diarias 

cax = divider.append_axes('bottom', size = '5%', pad = 0.1)
cax.tick_params(labelsize=15)

gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

gdf.plot(column = 'DEF_CUM', ax = ax, cax = cax, cmap = cmap, legend = True, legend_kwds={'orientation':'horizontal'})
plt.title('Defunciones acumuladas por 100 mil habs.\n',fontsize=20)
plt.savefig(path2 + 'cdmx-def-acum.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# <ipython-input-16-0f038c3ef13c>:17: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

# %%
fig, ax = plt.subplots(figsize = (15,11))
divider = make_axes_locatable(ax)

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)

#import matplotlib as mpl
#
#cmap = mpl.cm.Reds(np.linspace(0,1,20))
#cmap = mpl.colors.ListedColormap(cmap[5:,:-1])

# Defunciones diarias 

cax = divider.append_axes('bottom', size = '5%', pad = 0.1)
cax.tick_params(labelsize=15)

gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

gdf.plot(column = 'CASO_DIA', ax = ax, cax = cax, cmap = cmap, legend = True, legend_kwds={'orientation':'horizontal'})
plt.title('Contagios diarios por 100 mil habs.\n',fontsize=20)
plt.savefig(path2 + 'cdmx-casos-dia.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# <ipython-input-17-9812b700dd99>:17: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center'),axis=1)

# %%
fig, ax = plt.subplots(figsize = (15,11))
divider = make_axes_locatable(ax)

ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)

#import matplotlib as mpl
#
#cmap = mpl.cm.Reds(np.linspace(0,1,20))
#cmap = mpl.colors.ListedColormap(cmap[5:,:-1])

# Defunciones diarias 

cax = divider.append_axes('bottom', size = '5%', pad = 0.1)
cax.tick_params(labelsize=15)

gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center', fontsize=12),axis=1)

gdf.plot(column = 'CASO_CUM', ax = ax, cax = cax, cmap = cmap, legend = True, legend_kwds={'orientation':'horizontal'})
plt.title('Contagios acumulados por 100 mil habs.\n',fontsize=20)
plt.savefig(path2+'cdmx-casos-acum.png', bbox_inches='tight')
plt.show()
plt.clf()
# Out:
# <ipython-input-18-3602220d7dc5>:17: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   gdf.apply(lambda x: ax.annotate(s=x.CLAVE_MUNICIPIO, xy=x.geometry.centroid.coords[0], ha='center', fontsize=12),axis=1)
